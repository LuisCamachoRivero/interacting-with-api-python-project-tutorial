# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()
# Out:
# True

# %%
# Se crea el archivo .env para guardar ahi la informacion que no deseamos compartir

client_id = os.environ.get('CLIENT_ID')
client_secret = os.environ.get('CLIENT_SECRET')

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

con = spotipy.Spotify(auth_manager= SpotifyClientCredentials(client_id=client_id,client_secret=client_secret))

# %%
id_artista = '5C8KyBfvAz9PSaOd30eIow'

response = con.artist_top_tracks(id_artista)

print(response)
# Out:
# {'tracks': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5C8KyBfvAz9PSaOd30eIow'}, 'href': 'https://api.spotify.com/v1/artists/5C8KyBfvAz9PSaOd30eIow', 'id': '5C8KyBfvAz9PSaOd30eIow', 'name': 'Macross 82-99', 'type': 'artist', 'uri': 'spotify:artist:5C8KyBfvAz9PSaOd30eIow'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/4mk2tlpNn3mQKa6TlNNhnc'}, 'href': 'https://api.spotify.com/v1/albums/4mk2tlpNn3mQKa6TlNNhnc', 'id': '4mk2tlpNn3mQKa6TlNNhnc', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273ea34552ad2126a956d6dc19a', 'width': 640, 'height': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e02ea34552ad2126a956d6dc19a', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d00004851ea34552ad2126a956d6dc19a', 'width': 64, 'height': 64}], 'is_playable': True, 'name': 'CHAM!', 'release_date': '2015-10-21', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri
# ...

# %%
df_tracks = pd.DataFrame.from_records(response['tracks'])
df_tracks['duration_min'] = df_tracks['duration_ms']/(1000*60)
df_tracks['duration_min'] = df_tracks['duration_min'].round(2)
df_tracks
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'single', 'artists': [{'externa...
# 4  {'album_type': 'single', 'artists': [{'externa...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'compilation', 'artists': [{'ex...
# 8  {'album_type': 'single', 'artists': [{'externa...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# ...

# %%
diagrama_de_correlacion = sns.scatterplot(data= df_tracks, x='popularity', y='duration_min')
fig = diagrama_de_correlacion.get_figure()
fig.savefig('scatter_plot.png')
